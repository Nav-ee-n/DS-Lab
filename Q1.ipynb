# %%
import matplotlib.pyplot as plt
import numpy as np
x=[5,10,15,20]
y=[45,79,145,234]
plt.title('Cricket')
plt.xlabel('Overs')
plt.ylabel('Runs')
plt.plot(x,y,linewidth=3,label='Score',color='green')
plt.legend()
plt.show()
