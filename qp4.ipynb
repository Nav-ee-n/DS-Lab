# %%
x1=[5,7,9]
x2=[8,13,15]
x3=[11,14,17]
x4=[13,17,6]
plt.bar(x1,x2,color="green",align="center")
plt.bar(x3,x4,color="blue",align="center")
plt.show()

# %%
x2=[8,13,15]
labels=['A','B','C']
colors=['cyan','red','purple']
explode=[0,1,0]
plt.pie(x2,labels=labels,colors=colors,explode=explode)
plt.show()
